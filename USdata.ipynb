# %%
from datetime import datetime
import requests
import json
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
api_key = 'AIzaSyB6XLDcLebjh_iTEuBD8PbTG-XlEs_Rvdk'

# %%
USdata1 = pd.read_csv('C:/Users/Deepak/Desktop/Data Mining/USvideos/USvideos.csv')

# %%
USdata1
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# 5      gHZ1Qz0KiKM      17.14.11
# 6      39idVpFF7NQ      17.14.11
# 7      nc99ccSXST0      17.14.11
# 8      jr9QtXwC9vc      17.14.11
# 9      TUmyygCMMGA      17.14.11
# 10     9wRQljFNDW8      17.14.11
# 11     VifQlJit6A0      17.14.11
# 12     5E4ZBSInqUU      17.14.11
# 13     GgVmn66oK_A      17.14.11
# 14     TaTleo4cOs8      17.14.11
# 15     kgaO45SyaO4      17.14.11
# 16     ZAQs-ctOqXQ      17.14.11
# 17     YVfyYrEmzgM      17.14.11
# 18     eNSN6qet1kE      17.14.11
# 19     B5HORANmzHw      17.14.11
# 20     vU14JY3x81A      17.14.11
# 21     6VhU_T463sU      17.14.11
# 22     _-aDHxoblr4      17.14.11
# 23     JBZTZZAcFTw      17.14.11
# 24     lZ68j2J_GOM      17.14.11
# 25     dRpNZV18N_g      17.14.11
# 26     fcVjitaM3LY      17.14.11
# ...

# %%
USdata

# %%
USdata_sorted = USdata.drop_duplicates(subset = 'video_id', keep = 'first')

# %%
USdata_sorted

# %%
USdata_sorted =  USdata_sorted[USdata_sorted.likes != 0]

# %%
USdata_sorted =  USdata_sorted[USdata_sorted.dislikes != 0]

# %%
USdata_sorted =  USdata_sorted[USdata_sorted.comment_count != 0]

# %%
USdata_sorted =  USdata_sorted[USdata_sorted.comments_disabled == False]

# %%
USdata_sorted =  USdata_sorted[USdata_sorted.ratings_disabled == False]

# %%
USdata_sorted =  USdata_sorted[USdata_sorted.video_error_or_removed == False]

# %%
USdata_sorted = USdata_sorted.sort_values(by = 'views', ascending = False)

# %%
USdata_sorted.index = range(0,len(USdata_sorted))

# %%
USdata_sorted = USdata_sorted.dropna()

# %%
USdata_sorted.index = range(0,len(USdata_sorted))

# %%
USdata_sorted

# %%
s = np.array_split(USdata_sorted,len(USdata_sorted)/49)

# %%
s = np.array_split(USdata1,len(USdata1)/49)

# %%
s = np.array_split(USdata2,len(USdata2)/49)

# %%
s = np.array_split(USdata3,len(USdata3)/49)

# %%
s

# %%
l = {}
for i in range(int(len(s))):
    l[str(i)] = s[i]['video_id']

# %%
l

# %%
len(l)

# %%
h = {}
for i in range(len(l)):
    

    parameters = {"part": "statistics",
                  "id": ",".join(l[str(i)]),
                  "key": api_key,
                  "maxResults": 50
                  }
    url = "https://www.googleapis.com/youtube/v3/videos"



    page = requests.request(method= 'get', url = url, params = parameters)
    h[str(i)]= json.loads(page.text)
    #print(page.text)

# %%
h = {}
for i in range(len(l)):
    

    parameters = {"part": "status",
                  "id": ",".join(l[str(i)]),
                  "key": api_key,
                  "maxResults": 50
                  }
    url = "https://www.googleapis.com/youtube/v3/videos"



    page = requests.request(method= 'get', url = url, params = parameters)
    h[str(i)]= json.loads(page.text)
    #print(page.text)

# %%
h

# %%
len(h)

# %%
y = {}
for i in range(len(h)):
    y[str(i)] = h[str(i)]['items']

# %%
y

# %%
len(y)

# %%
valid_id = []

for i in range(int(len(y))):
    for q in range(len(y[str(i)])):
        f = y[str(i)][q]['statistics']
        if ('viewCount' in f and 'likeCount' in f and 'dislikeCount' in f and 'commentCount' in f and 'favoriteCount' in f):
            ids = y[str(i)][q]['id']
        #likes = y[str(i)][q]['statistics']['likeCount']
            valid_id.append(ids)
        #datas5.update({ids:likes})

# %%
valid_id

# %%
len(valid_id)

# %%
del_index5 = []
for ids in range(len(USdata1)):
    a = USdata1['video_id'][ids]
    #if a not in datas1:
    if a not in valid_id:
        del_index5.append(ids)

# %%
del_index5

# %%
datas2 = []

for i in range(int(len(y))):
    for q in range(len(y[str(i)])):
        ids = y[str(i)][q]['id']
        
        datas2.append(ids)

# %%
datas2

# %%
len(datas2)

# %%
datas1 = []

for i in range(len(y)):
    for q in range(len(y[str(i)])):
        if (y[str(i)][q]['status']['publicStatsViewable'] == True and y[str(i)][q]['status']['privacyStatus'] == 'public'):# or y[str(i)][q]['status']['embeddable'] == True:
            ids = y[str(i)][q]['id']
        #likes = y[str(i)][q]['statistics']['likeCount']
            datas1.append(ids)
        #datas5.update({ids:likes})

# %%
datas1

# %%
len(datas1)

# %%
del_index7 = []
for ids in range(len(USdata2)):
    a = USdata2['video_id'][ids]
    #if a not in datas1:
    if a not in datas1:
        del_index7.append(ids)
    #return del_index

# %%
del_index7

# %%
len(del_index7)

# %%
datas7 = {}

for i in range(len(y)):
    for q in range(len(y[str(i)])):
        ids = y[str(i)][q]['id']
        likes = y[str(i)][q]['statistics']['likeCount']
        views = y[str(i)][q]['statistics']['viewCount']
        dislikes = y[str(i)][q]['statistics']['dislikeCount']
        comments = y[str(i)][q]['statistics']['commentCount']
        
        datas7.update({ids:[likes,views,dislikes,comments]})

# %%
datas7

# %%
len(datas7)

# %%
def likes():
    lik = []
    for key, value in datas7.items():
        li = int(value[0])
        lik.append(li)
    return lik

# %%
def views():
    v = []
    for key, value in datas7.items():
        li1 = int(value[1])
        v.append(li1)
    return v

# %%
def dislikes():
    dis = []
    for key, value in datas7.items():
        li2 = int(value[2])
        dis.append(li2)
    return dis

# %%
def comments():
    com = []
    for key, value in datas7.items():
        li3 = int(value[3])
        com.append(li3)
    return com

# %%
likes()

# %%
type(l1)

# %%
USdata3['cur_likes'] = likes()
USdata3['cur_views'] = views()
USdata3['cur_dislikes'] = dislikes()
USdata3['cur_comments'] = comments()

# %%
USdata3

# %%
USdata_f = USdata3.sort_values(by = 'cur_views', ascending = False)

# %%
USdata_f.index = range(0,len(USdata_f))

# %%
USdata_f

# %%
del_index3 = []
for ids in range(len(USdata_sorted)):
    a = USdata_sorted['video_id'][ids]
    #if a not in datas1:
    if a not in datas2:
        del_index3.append(ids)
    #return del_index

# %%
del_index3

# %%
len(del_index3)

# %%
USdata1= USdata_sorted.drop(USdata_sorted.index[del_index3])

# %%
USdata1.index = range(0,len(USdata1))

# %%
USdata1

# %%
USdata2= USdata1.drop(USdata1.index[del_index5])

# %%
USdata2.index = range(0,len(USdata2))

# %%
USdata2

# %%
USdata3 = USdata2.drop(USdata2.index[del_index7])

# %%
USdata3.index = range(0,len(USdata3))

# %%
USdata3

# %%
USdata_f.to_pickle('US_offline_data.sep11')

# %%
    

parameters = {"part": "statistics",
                  "id":'1P_VGXqS9MI',
                  "key": api_key,
                  "maxResults": 50
                  }
url = "https://www.googleapis.com/youtube/v3/videos"



page = requests.request(method= 'get', url = url, params = parameters)
j= json.loads(page.text)
print(page.text)
